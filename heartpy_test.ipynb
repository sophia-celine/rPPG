# %%
import heartpy as hp
import matplotlib.pyplot as plt
# Out:
# c:\Users\Sophia\miniconda3\Lib\site-packages\heartpy\datautils.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
data = hp.get_data('ecg_signal.csv')

plt.figure(figsize=(12,4))
plt.plot(data)
plt.show()

# %% [markdown]
# What this will do is segment the data into sections of 40 seconds each. In this example each window will have an overlap with the previous window of 25%, meaning each iteration the 40 second window moves by 30 seconds.

# %%
#run analysis
sample_rate = 250
wd, m = hp.process(data, sample_rate)


#visualise in plot of custom size
plt.figure(figsize=(12,4))
hp.plotter(wd, m)

# display computed measures
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 78.090888
# ibi: 768.335484
# sdnn: 25.480993
# sdsd: 20.796162
# rmssd: 26.852169
# pnn20: 0.240260
# pnn50: 0.025974
# hr_mad: 16.000000
# sd1: 18.986071
# sd2: 30.628190
# s: 1826.864401
# sd1/sd2: 0.619889
# breathingrate: 0.266667
# c:\Users\Sophia\miniconda3\Lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
m.keys()
# Out:
# dict_keys(['bpm', 'ibi', 'sdnn', 'sdsd', 'rmssd', 'pnn20', 'pnn50', 'hr_mad', 'sd1', 'sd2', 's', 'sd1/sd2', 'breathingrate', 'segment_indices'])

# %%
wd, m = hp.process_segmentwise(data, sample_rate=250.0, segment_width = 15, segment_overlap = 0.25)
m['bpm']
# Out:
# [np.float64(76.37906647807638),
#  np.float64(78.21075740944018),
#  np.float64(80.03369839932603),
#  np.float64(75.73632538569426),
#  np.float64(76.57402155416904),
#  np.float64(78.01213522103438),
#  np.float64(78.1464217164793),
#  np.float64(79.31844888366628),
#  np.float64(77.78738115816768),
#  np.float64(79.6311818943839)]

# %%
len(m['bpm'])
# Out:
# 13

# %%
plt.plot(m['bpm'])

# %%
gt = [77, 79, 80, 81, 80, 79, 78, 76, 75, 76, 77, 78, 79, 78, 77, 78, 79, 80, 81, 79, 78, 75, 76, 82, 80]
plt.plot(gt)

# %% [markdown]
# 77
# 79
# 80
# 81
# 80
# 79
# 78
# 76
# 75
# 76
# 77
# 78
# 79
# 78
# 77
# 78
# 79
# 80
# 81
# 79
# 78
# 75
# 76
# 82
# 80
#
# (25)

# %%
# 1560 FRAMES
with open("sp02_L9.txt", "r") as f:
    lines = f.readlines()

values = lines[2].split()
count = len(values)

print(count)
# Out:
# 2997

# %%
import cv2

cap = cv2.VideoCapture("L9-11-12-2025-16-04.avi")

frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
cap.release()

print(frame_count)
# Out:
# 2997

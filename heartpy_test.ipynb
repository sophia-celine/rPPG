# %%
import heartpy as hp
import matplotlib.pyplot as plt
# Out:
# c:\Users\Sophia\miniconda3\Lib\site-packages\heartpy\datautils.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
data = hp.get_data('ecg_signal.csv')

plt.figure(figsize=(12,4))
plt.plot(data)
plt.show()

# %% [markdown]
# What this will do is segment the data into sections of 40 seconds each. In this example each window will have an overlap with the previous window of 25%, meaning each iteration the 40 second window moves by 30 seconds.

# %%
#run analysis
sample_rate = 250
wd, m = hp.process(data, sample_rate)


#visualise in plot of custom size
plt.figure(figsize=(12,4))
hp.plotter(wd, m)

# display computed measures
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 77.596996
# ibi: 773.225806
# sdnn: 46.889788
# sdsd: 23.742080
# rmssd: 29.897834
# pnn20: 0.269790
# pnn50: 0.058158
# hr_mad: 28.000000
# sd1: 21.140834
# sd2: 62.881910
# s: 4176.358061
# sd1/sd2: 0.336199
# breathingrate: 0.208594
# c:\Users\Sophia\miniconda3\Lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
m.keys()
# Out:
# dict_keys(['bpm', 'ibi', 'sdnn', 'sdsd', 'rmssd', 'pnn20', 'pnn50', 'hr_mad', 'sd1', 'sd2', 's', 'sd1/sd2', 'breathingrate', 'segment_indices'])

# %%
wd, m = hp.process_segmentwise(data, sample_rate=250.0, segment_width = 10, segment_overlap = 0.25)
m['bpm']
# Out:
# [np.float64(77.12082262210797),
#  np.float64(78.70572802798425),
#  np.float64(84.07286314806166),
#  np.float64(84.8933391380061),
#  np.float64(81.55867693701857),
#  np.float64(80.14247551202138),
#  np.float64(80.35714285714286),
#  np.float64(77.55277897457992),
#  np.float64(75.75757575757575),
#  np.float64(81.419624217119),
#  np.float64(80.18092105263159),
#  np.float64(74.82993197278911),
#  np.float64(77.4526678141136),
#  np.float64(74.52574525745257),
#  np.float64(72.52747252747253),
#  np.float64(78.22685788787484),
#  np.float64(78.125),
#  np.float64(80.18092105263159),
#  np.float64(79.96446023989337),
#  np.float64(78.60262008733623),
#  np.float64(71.09004739336493),
#  np.float64(78.53403141361257),
#  np.float64(77.38607050730869),
#  np.float64(74.42489851150204),
#  np.float64(77.15387912558937),
#  np.float64(76.036866359447),
#  np.float64(79.05138339920948),
#  np.float64(80.82622361921868),
#  np.float64(78.49978194505015),
#  np.float64(74.52574525745257),
#  np.float64(77.15387912558937),
#  np.float64(77.22007722007721),
#  np.float64(78.09110629067244),
#  np.float64(77.58620689655172),
#  np.float64(78.3630822812364),
#  np.float64(79.71656333038088),
#  np.float64(77.03081232492997),
#  np.float64(79.08611599297012),
#  np.float64(79.64601769911503),
#  np.float64(80.68130883012103),
#  np.float64(75.56675062972292),
#  np.float64(81.63265306122449),
#  np.float64(69.97455470737913),
#  np.float64(70.12622720897616),
#  np.float64(75.53503986571548),
#  np.float64(71.2127751402676),
#  np.float64(70.87628865979381),
#  np.float64(76.1070110701107),
#  np.float64(78.09110629067244),
#  np.float64(76.9589552238806),
#  np.float64(77.90368271954675),
#  np.float64(77.61966364812419),
#  np.float64(74.8978665456196),
#  np.float64(74.39134355275023),
#  np.float64(70.38948850305022),
#  np.float64(78.98200965335674),
#  np.float64(83.40461933276305),
#  np.float64(82.07934336525308),
#  np.float64(77.15387912558937),
#  np.float64(84.63541666666667),
#  np.float64(81.74386920980926),
#  np.float64(72.81553398058253),
#  np.float64(75.82720588235294)]

# %%
len(m['bpm'])
# Out:
# 63

# %%
plt.plot(m['bpm'])

# %%
gt = [77, 79, 80, 81, 80, 79, 78, 76, 75, 76, 77, 78, 79, 78, 77, 78, 79, 80, 81, 79, 78, 75, 76, 82, 80]
plt.plot(gt)

# %% [markdown]
# 77
# 79
# 80
# 81
# 80
# 79
# 78
# 76
# 75
# 76
# 77
# 78
# 79
# 78
# 77
# 78
# 79
# 80
# 81
# 79
# 78
# 75
# 76
# 82
# 80
#
# (25)

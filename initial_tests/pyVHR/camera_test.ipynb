# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt

pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r'C:\Users\Sophia\Documents\rPPG\initial_tests\videos\android.mp4', roi_approach="patches", roi_method="faceparsing")

plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyVHR.analysis.pipeline import Pipeline
#       2 import matplotlib.pyplot as plt
#       4 pipe = Pipeline()
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\__init__.py:1
# ----> 1 import pyVHR.extraction
#       2 import pyVHR.BVP
#       3 import pyVHR.BPM
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\extraction\__init__.py:1
# ----> 1 from .sig_processing import *
#       2 from .skin_extraction_methods import *
#       3 from .sig_extraction_methods import *
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\extraction\sig_processing.py:7
#       5 from pyVHR.extraction.skin_extraction_methods import *
#       6 from pyVHR.extraction.sig_extraction_methods import *
# ----> 7 from pyVHR.utils.cuda_utils import *
#       9 """
#      10 This module defines classes or methods used for Signal extraction and processing.
#      11 """
#      13 class SignalProcessing():
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\utils\__init__.py:2
#       1 from .cuda_utils import *
# ----> 2 from .errors import *
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\utils\errors.py:3
#       1 import numpy as np
#       2 import plotly.graph_objects as go
# ----> 3 from pyVHR.plot.visualize import VisualizeParams
#       4 from pyVHR.BPM.utils import Welch
#       5 from pyVHR.extraction.utils import sliding_straded_win_idx
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\plot\__init__.py:1
# ----> 1 from .visualize import *
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\plot\visualize.py:288
#     284     fig.update_layout(paper_bgcolor='#eee')
#     285     fig.show(renderer=VisualizeParams.renderer)
# --> 288 from pyVHR.BPM.utils import Model, gaussian, Welch, Welch_cuda, pairwise_distances, circle_clustering, optimize_partition, gaussian_fit
#     289 def visualize_BVPs_PSD_clutering(GT_BPM, GT_times , BVPs, times, fps, minHz=0.65, maxHz=4.0, out_fact=1):
#     290     """
#     291     TODO: documentare
#     292     This method create a plotly plot for visualizing the Power Spectral Density of a window of a windowed BVP signal. This method must be called
#    (...)    301
#     302     """
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\BPM\__init__.py:1
# ----> 1 from .BPM import *
#       2 from .utils import *
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\BPM\BPM.py:6
#       4 import plotly.graph_objects as go
#       5 from pyVHR.plot.visualize import VisualizeParams
# ----> 6 from pyVHR.BPM.utils import *
#       7 from scipy.stats import median_abs_deviation as mad
#       8 from pyVHR.extraction.utils import *
#
# File c:\Users\Sophia\venv312\Lib\site-packages\pyVHR\BPM\utils.py:10
#       8 import numpy as np
#       9 from scipy.signal import welch
# ---> 10 import cusignal
#      11 import cupy
#      13 def Welch(bvps, fps, minHz=0.65, maxHz=4.0, nfft=2048):
#
# ModuleNotFoundError: No module named 'cusignal'
